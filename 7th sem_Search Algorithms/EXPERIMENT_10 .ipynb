# %% [markdown]
# #### **NAME:** Swapan Chetri
# #### **QID:** 19030205
# #### **ROLL Number:** 1901313020
# #### B.TECH (CSE AIML), 4th Year

# %% [markdown]
# ### **EXPERIMENT 10:**  Explain a use case and implement Stochastic hill climbing algorithm using python.

# %% [markdown]
# ### **Code:**
# We will create a simple use case on the greetings “Hello World”. We will try to generate
# random solutions and see how close they are to Hello World. While evaluating the solutions
# if our solution is the best one then the algorithm stops else it keeps on moving to the next
# steps.

# %%
import random
import string

#random solution generates
def random_solution(length=13):
    return [random.choice(string.printable) for _ in range(length)]

#evaluate a solution
def evaluate_sol(solution):
    target = list ("Hello, World!")
    diff = 0
    for i in range(len(target)):
        s = solution[i]
        t = target[i]
        diff += abs(ord(s) - ord(t))
    return diff	

#mutating a solution
def mutate_sol(solution):
    index = random.randint(0, len(solution) - 1)
    solution[index] = random.choice(string.printable)

best = random_solution()
best_score = evaluate_sol(best)


while True:
    print ('Best score so far', best_score, 'Solution', "". join(best))

    if best_score == 0:
        break

    new_solution = list(best)
    mutate_sol(new_solution)



    score = evaluate_sol(new_solution)
    if evaluate_sol(new_solution) < best_score:
        best = new_solution
        best_score = score
# Out:
# Best score so far 499 Solution QPh,8=p=w*Ds
# Best score so far 499 Solution QPh,8=p=w*Ds
# Best score so far 414 Solution QjPh,8=p=w*Ds
# Best score so far 413 Solution QjPh-8=p=w*Ds
# Best score so far 413 Solution QjPh-8=p=w*Ds
# Best score so far 413 Solution QjPh-8=p=w*Ds
# Best score so far 413 Solution QjPh-8=p=w*Ds
# Best score so far 352 Solution QjPhj8=p=w*Ds
# Best score so far 271 Solution QjPhj8=p=w*D"
# Best score so far 271 Solution QjPhj8=p=w*D"
# Best score so far 271 Solution QjPhj8=p=w*D"
# Best score so far 271 Solution QjPhj8=p=w*D"
# Best score so far 268 Solution QjPhj8=A=w*D"
# Best score so far 268 Solution QjPhj8=A=w*D"
# Best score so far 265 Solution QjPhm8=A=w*D"
# Best score so far 265 Solution QjPhm8=A=w*D"
# Best score so far 256 Solution QjPhm)=A=w*D"
# Best score so far 256 Solution QjPhm)=A=w*D"
# Best score so far 256 Solution QjPhm)=A=w*D"
# Best score so far 256 Solution QjPhm)=A=w*D"
# Best score so far 256 Solution QjPhm)=A=w*D"
# ...
